# %%
import sys
sys.path.append('../')

from utils import get_test_coin_data, plot_agent_actions, plot_indicator

sys.path.append('../../')
from agents.basic.average_directional_index import AdxAgent

# %%
# load data
coin_data = get_test_coin_data()

adx_agent = AdxAgent()
plot_indicator(coin_data, adx_agent, [adx_agent.ADX])

# plot ADX indicator strength on top of price chart

# TODO: method in Agent that specifies if indicator strength is normalized or not

# compare with TradingView's ADX indicator for the same time period

# %% [markdown]
# ![alternatvie text](https://i.imgur.com/Oqttuko.png)

# %% [markdown]
# Could be that the EMA is fxcked
# But the agent can adjust its weights...
