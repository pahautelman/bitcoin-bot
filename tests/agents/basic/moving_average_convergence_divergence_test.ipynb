# %%
import sys
sys.path.append('../')

from utils import get_short_test_coin_data, get_test_coin_data, plot_indicator, plot_indicator_strength, plot_actions

sys.path.append('../../')
from agents.basic.moving_average_convergence_divergence import MacdAgent

# %%
coin_data = get_short_test_coin_data()

macd_agent = MacdAgent()
plot_indicator(coin_data, macd_agent, [macd_agent.MACD, macd_agent.SIGNAL], overlap_indicators=True)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plot_indicator_strength(coin_data, macd_agent)

# %%
plot_actions(coin_data, macd_agent)
