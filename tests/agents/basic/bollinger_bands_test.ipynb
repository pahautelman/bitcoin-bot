# %%
import sys
sys.path.append('../')

from utils import get_test_coin_data, get_short_test_coin_data, plot_indicator, plot_indicator_strength

sys.path.append('../../')
from agents.basic.bollinger_bands import BbAgent

# %%
coin_data = get_short_test_coin_data()

bb_agent = BbAgent()
plot_indicator(coin_data, bb_agent, [bb_agent.UPPER_BAND, bb_agent.LOWER_BAND, bb_agent.ROLLING_MEAN], overlap=True)

# %% [markdown]
# ![alternative text](https://i.imgur.com/PxXq03A.png)

# %%
plot_indicator_strength(coin_data, bb_agent)
