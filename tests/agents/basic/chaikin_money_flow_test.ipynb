# %%
import sys
sys.path.append('../')

from utils import get_short_test_coin_data, plot_indicator, plot_indicator_strength

sys.path.append('../../')
from agents.basic.chaikin_money_flow import CmfAgent

# %%
coin_data = get_short_test_coin_data()

cmf_agent = CmfAgent()
plot_indicator_strength(coin_data, cmf_agent)

# %% [markdown]
# ![alternatice text](https://i.imgur.com/K49jfo7.png)
