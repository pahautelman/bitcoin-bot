# %%
import sys
sys.path.append('../')

from utils import get_test_coin_data, plot_indicator, plot_indicator_strength

sys.path.append('../../')
from agents.basic.average_true_range import AtrAgent

# %%
coin_data = get_test_coin_data()

atr_agent = AtrAgent()
plot_indicator(coin_data, atr_agent, [atr_agent.ATR], overlap=False)

# %% [markdown]
# ![alternative text](https://i.imgur.com/zg4ito3.png)

# %% [markdown]
# LGTM!
