# %%
import sys
sys.path.append('../')

from utils import get_test_coin_data, plot_indicator

sys.path.append('../../')
from agents.basic.simple_moving_average import SmaAgent

# %%
coin_data = get_test_coin_data()

sma_agent = SmaAgent()
plot_indicator(coin_data, sma_agent, [sma_agent.SMA], overlap=True)

# %% [markdown]
# ![alternative text](https://i.imgur.com/BKWoOUM.png)
