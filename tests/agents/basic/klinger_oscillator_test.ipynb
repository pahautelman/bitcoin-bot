# %%
import sys
sys.path.append('../')

from utils import get_test_coin_data, plot_indicator_strength

sys.path.append('../../')
from agents.basic.klinger_oscillator import KoAgent

# %%
coin_data = get_test_coin_data()

ko_agent = KoAgent()
plot_indicator_strength(coin_data, ko_agent)
# Out:
# /home/pahautelman/Projects/bitcoin-bot/bitcoin-bot/tests/agents/basic/../../../agents/basic/klinger_oscillator.py:122: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cm[0] = dm[0]
# /home/pahautelman/Projects/bitcoin-bot/bitcoin-bot/tests/agents/basic/../../../agents/basic/klinger_oscillator.py:122: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   cm[0] = dm[0]
# ...

# %% [markdown]
# ![alternative text](https://i.imgur.com/RjhyPMU.png)

# %% [markdown]
# IDK! I'm not a trader, but I'm sure there's a way to use this to make money. I'm just here to make the tools.
