# %%
import sys
sys.path.append('../')

from utils import get_test_coin_data, plot_indicator

sys.path.append('../../')
from agents.basic.on_balance_volume import ObvAgent

# %%
coin_data = get_test_coin_data()

obv_agent = ObvAgent()
plot_indicator(coin_data, obv_agent, [obv_agent.OBV], overlap=False)

# %% [markdown]
# ![alternate text](https://i.imgur.com/NJ6d9VF.png)

# %% [markdown]
# The values are huge and it looks like they add up from the start. This is because the values are cumulative. We can fix this by using the pct_change() function to get the percentage change between the current and a prior element. This will give us the percentage change in volume.
