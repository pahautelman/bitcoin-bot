# %%
import sys
sys.path.append('../')

from utils import get_test_coin_data, plot_indicator, plot_indicator_strength

sys.path.append('../../')
from agents.basic.sentiment_analysis import SentimentAnalysisAgent

# %%
coin_data = get_test_coin_data()

sa_agent = SentimentAnalysisAgent()
plot_indicator(coin_data, sa_agent, [sa_agent.SENTIMENT_ANALYSIS], overlap=False)

# %% [markdown]
# ![alternative-text](https://i.imgur.com/rHNTqce.png)

# %% [markdown]
# Note that the values look borked compared to the reference chart, but i checked and they are correct. Must be different API.

# %%
plot_indicator_strength(coin_data, sa_agent)
