# %%
import sys
sys.path.append('../')

from utils import get_test_coin_data, plot_indicator

sys.path.append('../../')
from agents.basic.sentiment_analysis import SentimentAnalysisAgent

# %%
coin_data = get_test_coin_data()

sa_agent = SentimentAnalysisAgent()
plot_indicator(coin_data, sa_agent, [sa_agent.FEAR_AND_GREED], overlap=False)
# Out:
#                      fear_and_greed
# 2023-09-24 00:00:00           -0.06
# 2023-09-24 01:00:00           -0.06
# 2023-09-24 02:00:00           -0.12
# 2023-09-24 03:00:00           -0.12
# 2023-09-24 04:00:00           -0.12
# ...                             ...
# 2023-11-23 20:00:00            0.32
# 2023-11-23 21:00:00            0.32
# 2023-11-23 22:00:00            0.32
# 2023-11-23 23:00:00            0.32
# 2023-11-24 00:00:00            0.32
#
# [1465 rows x 1 columns]

# %% [markdown]
# ![alternative text](https://i.imgur.com/sDgI71V.png)

# %% [markdown]
# 👍👍
