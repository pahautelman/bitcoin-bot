# %%
import sys
sys.path.append('../')

from utils import get_short_test_coin_data, plot_indicator

sys.path.append('../../')
from agents.basic.fibonacci_retracement import FibonacciRetracementAgent

# %%
# load data
coin_data = get_short_test_coin_data()

pivot_fib_agent = FibonacciRetracementAgent()
plot_indicator(coin_data, pivot_fib_agent, 
    [
        # pivot_fib_agent.R1,
        pivot_fib_agent.R2,
        # pivot_fib_agent.R3,
        # pivot_fib_agent.R4,
        # pivot_fib_agent.S1,
        pivot_fib_agent.S2,
        # pivot_fib_agent.S3,
        # pivot_fib_agent.S4,
    ],
    overlap=True
)

# %%
pivot_fib = pivot_fib_agent.get_indicator(coin_data)
pivot_fib_agent._get_simple_action(coin_data, pivot_fib)
# Out:
# ('BUY',
#  R4    26972.690707
#  R3    26953.506667
#  R2    26934.322627
#  R1    26922.470707
#  S1    26884.102627
#  S2    26872.250707
#  S3    26853.066667
#  S4    26833.882627
#  Name: 2023-09-30 00:00:00, dtype: float64)
