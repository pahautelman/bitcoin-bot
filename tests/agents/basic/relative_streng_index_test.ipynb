# %%
import sys
sys.path.append('../')

from utils import get_test_coin_data, plot_indicator, plot_indicator_strength, plot_actions

sys.path.append('../../')
from agents.basic.relative_strength_index import RsiAgent

# %%
coin_data = get_test_coin_data()

rsi_agent = RsiAgent(window=14, smoothing_window=3)
plot_indicator(coin_data, rsi_agent, [rsi_agent.RSI], overlap=False)

# %% [markdown]
# ![alternative text](https://i.imgur.com/Ak2pEvy.png)

# %%
plot_indicator_strength(coin_data, rsi_agent)

# %%
plot_actions(coin_data, rsi_agent)
