# %%
import sys
sys.path.append('../')

from utils import get_test_coin_data, plot_indicator_strength, plot_actions

sys.path.append('../../')
from agents.strategies.BB_RSI_agent import BbRsiAgent

# %%
coin_data = get_test_coin_data()

bb_rsi_agent = BbRsiAgent(rsi_oversold=25, rsi_overbought=75)
plot_actions(coin_data, bb_rsi_agent)
plot_indicator_strength(coin_data, bb_rsi_agent)
