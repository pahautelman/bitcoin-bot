# %%
import sys
sys.path.append('../')

from utils import get_test_coin_data, plot_actions

sys.path.append('../../')
from agents.strategies.MACD_RSI_agent import MacdRsiAgent

# %%
coin_data = get_test_coin_data()

macd_rsi_agent = MacdRsiAgent(rsi_oversold=40, rsi_overbought=60)
plot_actions(coin_data, macd_rsi_agent)
