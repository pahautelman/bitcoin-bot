# %%
import sys
sys.path.append('../')

from utils import get_test_coin_data, plot_indicator_strength, plot_indicator, plot_actions

sys.path.append('../../')
from agents.basic.average_directional_index import AdxAgent

# %%
coin_data = get_test_coin_data()

adx_agent = AdxAgent(window=14)
plot_indicator(coin_data, adx_agent, [adx_agent.ADX])

# %% [markdown]
# ![alternatvie text](https://i.imgur.com/Oqttuko.png)

# %% [markdown]
# Looks good! Except for the high initial ADX values, the indicator looks close to the TradingView data.

# %%
plot_indicator_strength(coin_data, adx_agent)

# %%
plot_actions(coin_data, adx_agent)
