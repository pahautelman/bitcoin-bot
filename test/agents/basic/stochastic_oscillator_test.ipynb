# %%
import sys
sys.path.append('../')

from utils import get_short_test_coin_data, plot_indicator, plot_indicator_strength

sys.path.append('../../')
from agents.basic.stochastic_oscillator import SoAgent

# %%
coin_data = get_short_test_coin_data()

so_agent = SoAgent()
plot_indicator(coin_data, so_agent, [so_agent.SO], overlap=False)

# %% [markdown]
# ![alternative text](https://i.imgur.com/VMcVjqE.png)

# %%
plot_indicator_strength(coin_data, so_agent)
