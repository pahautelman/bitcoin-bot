# %%
import sys
sys.path.append('../')

from utils import get_test_coin_data, plot_indicator

sys.path.append('../../')
from agents.basic.exponential_moving_average import EmaAgent

# %%
coin_data = get_test_coin_data()

ema_agent = EmaAgent(window=50)
plot_indicator(coin_data, ema_agent, [ema_agent.EMA], overlap=True)

# %% [markdown]
# ![alternative text](https://i.imgur.com/WDRDbOX.png)

# %% [markdown]
# LGTM!
